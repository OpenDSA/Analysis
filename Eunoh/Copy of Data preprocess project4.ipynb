# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you uploaded your homework
customized_path_to_homework = "/content/drive/Shared drives/thesis"
sys.path.append(customized_path_to_homework)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
original = pd.read_excel("/content/drive/Shareddrives/thesis/C_Project4_Origin.xlsx")
# sB = pd.read_excel("/content/drive/Shared drives/thesis/Project4_StrugglingBean.xlsx")

# %% [markdown]
# Start of the Code

# %%
#Reading how distributed the grades are for Project 4 for Fall 2021
distribution = original.distribution

# %%
import collections
counter=collections.Counter(distribution * 10)
print(counter)
# Out:
# Counter({100.0: 137, 90.0: 114, 80.0: 81, 70.0: 72, 60.0: 32, 50.0: 26, 30.0: 15, 40.0: 12})

# %%
#bar chart for grade distribution
plt.bar(counter.keys(), counter.values(), width = 6)
plt.ylim(0, 140)
plt.xlabel("Grade of project4")
plt.ylabel('Number of students')
counter.values()
# Out:
# dict_values([15, 12, 26, 32, 72, 81, 114, 137])

# %% [markdown]
# Start reading survey data for preprocess.

# %%
survey = pd.read_excel("/content/drive/My Drive/research data_actual/SurveyData.xlsx")

# %%
#Calculating how distributed the answers are for survey questions (example is with question8, if you want to see other question replace Q8 to different question such as Q4)
surDis1 = survey.Q8.astype(str)
counter2=collections.Counter(surDis1)
print(counter2)
# Out:
# Counter({'Difficult': 187, 'Very difficult': 89, 'Not difficult': 56, 'Easy': 15})

# %%
surDis = survey.Q8.astype(str)

# %%
counter1=collections.Counter(surDis)
print(counter1)
# Out:
# Counter({'Difficult': 187, 'Very difficult': 89, 'Not difficult': 56, 'Easy': 15})

# %%
#how distributed answers are for question asking how difficult was project 4?
plt.bar(counter1.keys(), counter1.values())
plt.xlabel("How difficult was the project?")
plt.ylabel('Number of students')
counter1.values()
# Out:
# dict_values([187, 56, 89, 15])

# %%
surveyTemp = pd.read_excel("/content/drive/My Drive/research data_actual/SurveyData.xlsx")

# %% [markdown]
# survey data preprocessing from string to int

# %%
#converting answers for survey questions to numbers

from re import A
#converting grade each student received for project 4 to numerical values
def categorize_grade(aDataobj):
  if ('90 and above') in aDataobj :
    return 1
  elif('80-89') in aDataobj:
    return 2
  elif('70-79') in aDataobj:
    return 3
  elif('60-69') in aDataobj:
    return 4
  elif('Below 60') in aDataobj:
    return 5
#converting answers for how much help did you receive from office hours and piazza to numerical values
def categorize_helpTA(aDataobj):
  if ('None') in aDataobj :
    return 1
  elif('5 or less') in aDataobj:
    return 2
  elif('6 to 10') in aDataobj:
    return 3
  elif('More than 10 times') in aDataobj:
    return 4
    #converting answers for how often did you attend lecture to numerical values
def categorize_lecture(aDataobj):
  if ('all lectures.') in aDataobj :
    return 1
  elif('most lectures.') in aDataobj:
    return 2
  elif('more than half the lectures.') in aDataobj:
    return 3
  elif('less than half the lectures.') in aDataobj:
    return 4
  elif('only a few lectures.') in aDataobj:
    return 5

#converting answer for if interaction with Staff has helped to numerical values
def categorize_interactionHelped(aDataobj):
  if ('Strongly Agree') in aDataobj :
    return 1
  elif('Agree') in aDataobj:
    return 2
  elif('Disagree') in aDataobj:
    return 3
  elif('Strongly Disagree') in aDataobj:
    return 4

#converting answer for how often did you use outside source? to numerical values
def categorize_outsideSource(aDataobj):
  if ('None') in aDataobj :
    return 1
  elif('5 or less') in aDataobj:
    return 2
  elif('6 to 10') in aDataobj:
    return 3
  elif('More than 10 times') in aDataobj:
    return 4
#converting answers for how difficult was the project to numerical values
def categorize_difficultness(aDataobj):
  if ('Easy') in aDataobj :
    return 1
  elif('Not difficult') in aDataobj:
    return 2
  elif('Difficult') in aDataobj:
    return 3
  elif('Very difficult') in aDataobj:
    return 4
#converting answers for if you had sufficient help to numerical values
def categorize_sufficientHelp(aDataobj):
  if ('Strongly Agree') in aDataobj :
    return 1
  elif('Agree') in aDataobj:
    return 2
  elif('Disagree') in aDataobj:
    return 3
  elif('Strongly Disagree') in aDataobj:
    return 4

# %%
surveyTemp['Q6'] = survey['Q6'].apply(categorize_grade)
surveyTemp['Q11'] = survey['Q11'].apply(categorize_helpTA)
surveyTemp['Q4'] = survey['Q4'].apply(categorize_lecture)
surveyTemp['Q14'] = survey['Q14'].apply(categorize_interactionHelped)
surveyTemp['Q10'] = survey['Q10'].apply(categorize_outsideSource)
surveyTemp['Q8'] = survey['Q8'].apply(categorize_difficultness)
surveyTemp['Q13'] = survey['Q13'].apply(categorize_sufficientHelp)

# %%
surveyTemp
# Out:
#                                                     Q1  \
# 0    I consent to participating and having my surve...
# 1    I consent to participating and having my surve...
# 2    I consent to participating and having my surve...
# 3    I consent to participating and having my surve...
# 4    I consent to participating and having my surve...
# ..                                                 ...
# 342  I consent to participating and having my surve...
# 343  I consent to participating and having my surve...
# 344  I consent to participating and having my surve...
# 345  I consent to participating and having my surve...
# 346  I consent to participating and having my surve...
#
#                          Q2  \
# 0    I am 18 years or older
# 1    I am 18 years or older
# 2    I am 18 years or older
# 3    I am 18 years or older
# 4    I am 18 years or older
# ..                      ...
# 342  I am 18 years or older
# 343  I am 18 years or older
# 344  I am 18 years or older
# 345  I am 18 years or older
# 346  I am 18 years or older
#
#                                                     Q3  Q4  Q6   Q7  Q8   Q9  \
# 0    I treated this like I would a graded test and ...   1   4  4.0   3  3.0
# 1    I put some thought and effort into it but didn...   1   3  3.0   3  3.0
# 2    I treated this like I would a graded test and ...   1   3  3.0   3  3.0
# 3    I treated this like I would a graded test and ...   1   2  2.0   3  3.0
# 4    I put some thought and effort into it but didn...   1   2  2.0   3  3.0
# ..                                                 ...  ..  ..  ...  ..  ...
# 342   I did what was easy and skipped harder questions   5   1  1.0   4  4.0
# 343  I put some thought and effort into it but didn...   5   5  5.0   4  4.0
# 344  I put some thought and effort into it but didn...   5   5  5.0   4  4.0
# 345  I treated this like I would a graded test and ...   5   5  5.0   4  4.0
# 346  I treated this like I would a graded test and ...   1   1  1.0   3  3.0
#
#      Q10  Q11        Q12  Q13  Q14  \
# 0      1    2       None  2.0  2.0
# 1      3    2       None  2.0  2.0
# 2      2    2       None  2.0  2.0
# 3      1    2       None  2.0  2.0
# 4      2    2    6 to 10  2.0  2.0
# ..   ...  ...        ...  ...  ...
# 342    1    1       None  NaN  NaN
# 343    2    1  5 or less  2.0  NaN
# 344    1    1       None  2.0  NaN
# 345    2    1       None  1.0  NaN
# 346    1    1       None  1.0  1.0
#
#                                                    Q15
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Some of the requirements and feedback in Web-C...
# 4                                                  NaN
# ..                                                 ...
# 342                Project 4 was literally impossible.
# 343  I had more than enough resources at my fingert...
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
#
# [347 rows x 14 columns]

# %%
hp = pd.read_excel("/content/drive/My Drive/research data_actual/above80.xlsx")
lp = pd.read_excel("/content/drive/My Drive/research data_actual/less80.xlsx")
lp2 = pd.read_excel("/content/drive/My Drive/research data_actual/less80_2.xlsx")
hp
# Out:
#      index                                                 Q1  \
# 0      4.0  I consent to participating and having my surve...
# 1      5.0  I consent to participating and having my surve...
# 2      6.0  I consent to participating and having my surve...
# 3     27.0  I consent to participating and having my surve...
# 4     28.0  I consent to participating and having my surve...
# ..     ...                                                ...
# 221  317.0  I consent to participating and having my surve...
# 222  325.0  I consent to participating and having my surve...
# 223  330.0  I consent to participating and having my surve...
# 224  343.0  I consent to participating and having my surve...
# 225    NaN                                                NaN
#
#                          Q2  \
# 0    I am 18 years or older
# 1    I am 18 years or older
# 2    I am 18 years or older
# 3    I am 18 years or older
# 4    I am 18 years or older
# ..                      ...
# 221  I am 18 years or older
# 222  I am 18 years or older
# 223  I am 18 years or older
# 224  I am 18 years or older
# 225                     NaN
#
#                                                     Q3  \
# 0    I treated this like I would a graded test and ...
# 1    I put some thought and effort into it but didn...
# 2    I treated this like I would a graded test and ...
# 3    I treated this like I would a graded test and ...
# 4    I put some thought and effort into it but didn...
# ..                                                 ...
# 221  I put some thought and effort into it but didn...
# 222  I treated this like I would a graded test and ...
# 223  I treated this like I would a graded test and ...
# 224   I did what was easy and skipped harder questions
# 225                                                NaN
#
#                                Q4  Q4.1            Q5  Q5.1              Q6  \
# 0                   all lectures.   1.0         80-89   2.0       Difficult
# 1                   all lectures.   1.0         80-89   2.0       Difficult
# 2                   all lectures.   1.0         80-89   2.0       Difficult
# 3    less than half the lectures.   4.0         80-89   2.0       Difficult
# 4    less than half the lectures.   4.0         80-89   2.0       Difficult
# ..                            ...   ...           ...   ...             ...
# 221                 all lectures.   1.0  90 and above   1.0  Very difficult
# 222                 all lectures.   1.0  90 and above   1.0  Very difficult
# 223  more than half the lectures.   3.0  90 and above   1.0  Very difficult
# 224          only a few lectures.   5.0  90 and above   1.0  Very difficult
# 225                           NaN   NaN           NaN   NaN             NaN
#
#       Q7                  Q8                  Q9  Q9.1                 Q10  \
# 0    3.0                None           5 or less   2.0                None
# 1    3.0           5 or less           5 or less   2.0             6 to 10
# 2    3.0                None           5 or less   2.0                None
# 3    3.0                None           5 or less   2.0           5 or less
# 4    3.0           5 or less           5 or less   2.0           5 or less
# ..   ...                 ...                 ...   ...                 ...
# 221  4.0                None                None   1.0           5 or less
# 222  4.0  More than 10 times             6 to 10   3.0  More than 10 times
# 223  4.0  More than 10 times  More than 10 times   4.0                None
# 224  4.0                None                None   1.0                None
# 225  NaN                 NaN                 NaN   NaN                 NaN
#
#                    Q11  Q11.1                Q12     Q12.1  \
# 0                Agree    2.0              Agree  2.000000
# 1                Agree    2.0              Agree  2.000000
# 2                Agree    2.0              Agree  2.000000
# 3                Agree    2.0              Agree  2.000000
# 4                Agree    2.0              Agree  2.000000
# ..                 ...    ...                ...       ...
# 221     Strongly Agree    1.0     Strongly Agree  1.000000
# 222  Strongly disagree    NaN  Strongly disagree  4.000000
# 223              Agree    2.0  Strongly disagree  4.000000
# 224  Strongly disagree    NaN  Strongly disagree  4.000000
# 225                NaN    NaN                NaN  2.097778
#
#                                                    Q13
# 0    Some of the requirements and feedback in Web-C...
# 1                                                  NaN
# 2                                                  NaN
# 3    Please get rid of late penalties. My grade wou...
# 4    Project 4 was an accumulation of mostly easy m...
# ..                                                 ...
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                Project 4 was literally impossible.
# 225                                                NaN
#
# [226 rows x 19 columns]

# %% [markdown]
# Finding difference between HP and LP

# %%
difficultHp = hp.Q8.astype(str)
difficultLp = lp2.Q8.astype(str)

# %%
difficultLp
# Out:
# 0                 6 to 10
# 1               5 or less
# 2                    None
# 3               5 or less
# 4                    None
#               ...
# 117    More than 10 times
# 118                  None
# 119             5 or less
# 120    More than 10 times
# 121             5 or less
# Name: Q8, Length: 122, dtype: object

# %%
counterHP = collections.Counter(difficultHp)
print(counterHP)
# Out:
# Counter({'5 or less': 99, 'None': 89, '6 to 10': 24, 'More than 10 times': 13, 'nan': 1})

# %%
counterLP =collections.Counter(difficultLp)
print(counterLP)
# Out:
# Counter({'None': 49, '5 or less': 42, 'More than 10 times': 16, '6 to 10': 15})

# %%
# # evaluate a logistic regression model using k-fold cross-validation
# from numpy import mean
# from numpy import std
# from sklearn.datasets import make_classification
# from sklearn.model_selection import KFold
# from sklearn.model_selection import cross_val_score
# from sklearn.linear_model import LogisticRegression
# # create dataset
# X = temp.
# X, y = make_classification(n_samples=100, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# # prepare the cross-validation procedure
# cv = KFold(n_splits=5, random_state=1, shuffle=True)
# # create model
# model = LogisticRegression()
# # evaluate model
# scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# # report performance
# print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
