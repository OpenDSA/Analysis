# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you uploaded your homework
customized_path_to_homework = "/content/drive/My Drive/research data_actual"
sys.path.append(customized_path_to_homework)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn import linear_model
from scipy.stats import spearmanr
import numpy as np
from sklearn.linear_model import LinearRegression

from scipy.stats import linregress

# %%
original = pd.read_excel("/content/drive/My Drive/research data_actual/Original.xlsx")
origin = pd.read_excel("/content/drive/My Drive/research data_actual/Project4_Origin.xlsx")
piazza = pd.read_excel("/content/drive/My Drive/research data_actual/Piazza contribution.xlsx")

# %%
origin
# Out:
#       Course          User                Email   view  online  posts  \
# 0    CS 2114      andrewc0      andrewc0@vt.edu   37.0   130.0    0.0
# 1    CS 2114   jeremybruce   jeremybruce@vt.edu    0.0    43.0    0.0
# 2    CS 2114         zehua         zehua@vt.edu   67.0    27.0    0.0
# 3    CS 2114  nicholasmcho  nicholasmcho@vt.edu   67.0    63.0    0.0
# 4    CS 2114    benmathews    benmathews@vt.edu    0.0    17.0    0.0
# ..       ...           ...                  ...    ...     ...    ...
# 484  CS 2114        sofiak        sofiak@vt.edu   21.0    37.0    0.0
# 485  CS 2114   sslater2024   sslater2024@vt.edu  115.0   137.0    0.0
# 486  CS 2114      thriloks      thriloks@vt.edu    0.0    38.0    0.0
# 487  CS 2114     timlichen     timlichen@vt.edu   62.0   154.0    0.0
# 488  CS 2114       vhaxton       vhaxton@vt.edu   13.0    32.0    0.0
#
#      answers  NumVisit    Last Name        First Name  ...       Time  \
# 0        0.0       0.0         Choi            Andrew  ... 2021-04-10
# 1        0.0       4.0        Bruce     Jeremy Daniel  ... 2021-04-09
# 2        0.0       0.0        Zhang             Zehua  ... 2021-04-09
# 3        0.0       0.0          Cho  Nicholas Matthew  ... 2021-04-09
# 4        0.0       0.0      Mathews         Ben Bruce  ... 2021-04-07
# ..       ...       ...          ...               ...  ...        ...
# 484      0.0       0.0  Kazmierczak       Sofia Laine  ... 2021-04-08
# 485      1.0       8.0       Slater       Sierra Noel  ... 2021-04-07
# 486      0.0       0.0   Shivaraman           Thrilok  ... 2021-04-08
# 487      0.0       5.0         Chen            Tim Li  ... 2021-04-06
# 488      0.0       0.0       Haxton     Victoria Kaye  ... 2021-04-07
#
#      Correctness by thirdsubmission  Penalty/Bonus       Grade          TG  \
# 0                          0.000000          -10.0   25.000000   35.000000
# 1                          0.000000          -20.0   25.000000   45.000000
# 2                          0.772174           -5.0   25.000000   30.000000
# 3                          0.000000          -35.0   26.840504   61.840504
# 4                          0.000000          -15.0   27.045861   42.045861
# ..                              ...            ...         ...         ...
# 484                        0.838286            0.0  100.000000  100.000000
# 485                        0.000000            0.0  100.000000  100.000000
# 486                        0.978261            0.0  100.000000  100.000000
# 487                        0.902427            0.0  100.000000  100.000000
# 488                        0.811914            0.0  100.000000  100.000000
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 0       0.000000           3.0  1.620000e+12                   0.000000
# 1       0.000000           3.0  1.620000e+12                   0.000000
# 2       0.000000           3.0  1.620000e+12                   0.000000
# 3       0.000000           3.0  1.620000e+12                   0.000000
# 4       0.000000           3.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 484    30.271337          10.0  1.620000e+12                  30.271337
# 485     0.000000          10.0  1.620000e+12                   0.000000
# 486    29.813566          10.0  1.620000e+12                  29.813566
# 487     0.000000          10.0  1.620000e+12                   0.000000
# 488    17.478981          10.0  1.620000e+12                  17.478981
#
#      Correctness/Testing %
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# ..                     ...
# 484               0.864895
# 485               0.000000
# 486               0.851816
# 487               0.000000
# 488               0.499399
#
# [489 rows x 23 columns]

# %%
from openpyxl import load_workbook
wb = load_workbook("/content/drive/My Drive/research data_actual/Original.xlsx")
ws = wb.active

# %%
less_85 = original[original['TG'] < 80]
above_85 = original[original['TG'] >= 80]

less_85_2 = origin[origin['TG'] < 80]
above_85_2 = origin[origin['TG'] >= 80]

# %%
# spearman correlation
coef,p = spearmanr(less_85_2.view,less_85_2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.145

# %%
above_85_2.NumVisit.mean()
# Out:
# 3.4575342465753423

# %%
linregress(less_85_2.view, less_85_2.TG)
# Out:
# LinregressResult(slope=0.04152640717868057, intercept=66.19053314467745, rvalue=0.061635176978811775, pvalue=0.4964815491520048, stderr=0.06088205525263493)

# %%
# spearman correlation
coef,p = spearmanr(above_85_2.view,above_85_2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.160

# %%
linregress(above_85_2.view, above_85_2.TG)
# Out:
# LinregressResult(slope=0.030412689305045176, intercept=93.38562168264683, rvalue=0.14732737904859144, pvalue=0.004795824742072947, stderr=0.010716498010434138)

# %%
less_85_2
# Out:
#       Course          User                Email  view  online  posts  answers  \
# 0    CS 2114      andrewc0      andrewc0@vt.edu  37.0   130.0    0.0      0.0
# 1    CS 2114   jeremybruce   jeremybruce@vt.edu   0.0    43.0    0.0      0.0
# 2    CS 2114         zehua         zehua@vt.edu  67.0    27.0    0.0      0.0
# 3    CS 2114  nicholasmcho  nicholasmcho@vt.edu  67.0    63.0    0.0      0.0
# 4    CS 2114    benmathews    benmathews@vt.edu   0.0    17.0    0.0      0.0
# ..       ...           ...                  ...   ...     ...    ...      ...
# 196  CS 2114     lilykhoch     lilykhoch@vt.edu  37.0    64.0    0.0      0.0
# 197  CS 2114     adjeirenn     adjeirenn@vt.edu  42.0   117.0    0.0      0.0
# 198  CS 2114    chagerup24    chagerup24@vt.edu  18.0    40.0    0.0      0.0
# 199  CS 2114       jay1890       jay1890@vt.edu   0.0     0.0    0.0      0.0
# 201  CS 2114      atfuerst      atfuerst@vt.edu   0.0     8.0    0.0      0.0
#
#      NumVisit   Last Name           First Name  ...       Time  \
# 0         0.0        Choi               Andrew  ... 2021-04-10
# 1         4.0       Bruce        Jeremy Daniel  ... 2021-04-09
# 2         0.0       Zhang                Zehua  ... 2021-04-09
# 3         0.0         Cho     Nicholas Matthew  ... 2021-04-09
# 4         0.0     Mathews            Ben Bruce  ... 2021-04-07
# ..        ...         ...                  ...  ...        ...
# 196       0.0  Khochareun            Lily Ling  ... 2021-04-08
# 197       0.0       Adjei  Renny Afriyie-Antwi  ... 2021-04-08
# 198       0.0     Hagerup         Colin Edward  ... 2021-04-07
# 199       0.0      Kapoor            Jay Ashok  ... 2021-04-08
# 201       0.0      Fuerst        Andrew Thomas  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade         TG  \
# 0                          0.000000          -10.0  25.000000  35.000000
# 1                          0.000000          -20.0  25.000000  45.000000
# 2                          0.772174           -5.0  25.000000  30.000000
# 3                          0.000000          -35.0  26.840504  61.840504
# 4                          0.000000          -15.0  27.045861  42.045861
# ..                              ...            ...        ...        ...
# 196                        0.722408            0.0  79.616643  79.616643
# 197                        0.503902            0.0  79.618841  79.618841
# 198                        0.000000            0.0  79.653311  79.653311
# 199                        0.302160            0.0  79.944964  79.944964
# 201                        0.599212            0.0  79.972425  79.972425
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 0       0.000000           3.0  1.620000e+12                   0.000000
# 1       0.000000           3.0  1.620000e+12                   0.000000
# 2       0.000000           3.0  1.620000e+12                   0.000000
# 3       0.000000           3.0  1.620000e+12                   0.000000
# 4       0.000000           3.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 196    25.284281           8.0  1.620000e+12                  25.284281
# 197    17.549407           8.0  1.620000e+12                  17.549407
# 198     0.000000           8.0  1.620000e+12                   0.000000
# 199     0.000000           8.0  1.620000e+12                   0.000000
# 201    20.321768           8.0  1.620000e+12                  20.321768
#
#      Correctness/Testing %
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# ..                     ...
# 196               0.722408
# 197               0.501412
# 198               0.000000
# 199               0.000000
# 201               0.580622
#
# [124 rows x 23 columns]

# %%
filterAbove85 = above_85
# [(above_85["NumVisit"] > 0) & (above_85["Max Sub"] > 7) &((above_85["Correctness by thirdsubmission"] < 0.7))]
# filterLess85 = less_85[(less_85["Max Sub"] > 7) & (less_85["NumberOfDays"] > 3)]
filterLess85 = less_85
# [(less_85["Max Sub"] > 7) ]

filteredAbove85_Numvisit = above_85_2[above_85_2["NumVisit"] == 0]
filterAbove85_2 = above_85_2[(above_85_2["NumVisit"] > 0) & (above_85_2["Max Sub"] > 7) & (above_85_2["Correctness by thirdsubmission"] < 0.5)]
filterLess85_2 = less_85_2
# [(less_85_2["Max Sub"] > 7)]

# %%
filterNonVisit = filteredAbove85_Numvisit[(filteredAbove85_Numvisit["Max Sub"] > 7) & (filteredAbove85_Numvisit["Correctness by thirdsubmission"] < 0.5) & (filteredAbove85_Numvisit["NumberOfDays"] > 4)]

# %%
filtered = pd.concat([filterAbove85, filterLess85])
filtered2 = pd.concat([filterAbove85_2, filterLess85_2, filterNonVisit])

# %%
filterAbove85_temp = above_85_2[(above_85_2["Max Sub"] > 10) & (above_85_2["Correctness by thirdsubmission"] < 0.5)]
filterLess85_temp = less_85_2
filtered_temp = pd.concat([filterAbove85_temp, filterLess85_temp])

# %%
# spearman correlation
coef,p = spearmanr(filtered_temp.NumVisit,filtered_temp.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.313

# %%
# spearman correlation
coef,p = spearmanr(filtered.NumVisit,filtered.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.189

# %%
# spearman correlation
coef,p = spearmanr(filtered2.NumVisit,filtered2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.507

# %%
# spearman correlation
coef,p = spearmanr(filtered2.online,filtered2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.291

# %%
# spearman correlation
coef,p = spearmanr(filtered2.posts,filtered2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.249

# %%
# spearman correlation
coef,p = spearmanr(filtered2.answers,filtered2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.189

# %%
# spearman correlation
coef,p = spearmanr(piazza.answers,piazza.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.159

# %%
# spearman correlation
coef,p = spearmanr(piazza.posts,piazza.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.157

# %%
filteredAbove85_Numvisit_3 = above_85_2[ (above_85_2["posts"] == 0)]
filterAbove85_3 = above_85_2[(above_85_2["posts"] >0) & (above_85_2["Max Sub"] > 7) & (above_85_2["Correctness by thirdsubmission"] < 0.5)]
filterLess85_3 = less_85_2
# [(less_85_2["Max Sub"] > 7)]
filterNonVisit3 = filteredAbove85_Numvisit_3[(filteredAbove85_Numvisit_3["Max Sub"] > 7) & (filteredAbove85_Numvisit_3["Correctness by thirdsubmission"] < 0.5) & (filteredAbove85_Numvisit_3["NumberOfDays"] > 4)]
filterNonVisit3
# Out:
#       Course          User                Email   view  online  posts  \
# 81   CS 2114        yunqin        yunqin@vt.edu    0.0    90.0    0.0
# 83   CS 2114     kshingala     kshingala@vt.edu   23.0    54.0    0.0
# 85   CS 2114      ahanumai      ahanumai@vt.edu   16.0    71.0    0.0
# 102  CS 2114       bmeghna       bmeghna@vt.edu   30.0    60.0    0.0
# 117  CS 2114        rowanc        rowanc@vt.edu  102.0    93.0    0.0
# 143  CS 2114     simrank20     simrank20@vt.edu   32.0   218.0    0.0
# 169  CS 2114  jstonebraker  jstonebraker@vt.edu   11.0   102.0    0.0
# 299  CS 2114        pmihir        pmihir@vt.edu    0.0    15.0    0.0
# 309  CS 2114      hurayrah      hurayrah@vt.edu    3.0    41.0    0.0
# 331  CS 2114       moonk19       moonk19@vt.edu    1.0    14.0    0.0
# 360  CS 2114          van7          van7@vt.edu  110.0    60.0    0.0
# 376  CS 2114      caitlyns      caitlyns@vt.edu    9.0    38.0    0.0
# 383  CS 2114      saiyerra      saiyerra@vt.edu   16.0    66.0    0.0
# 411  CS 2114      aniket19      aniket19@vt.edu   21.0    71.0    0.0
# 427  CS 2114       kyle913       kyle913@vt.edu    0.0    11.0    0.0
#
#      answers  NumVisit    Last Name         First Name  ...       Time  \
# 81       0.0      82.0         Yang            Yun Qin  ... 2021-04-08
# 83       0.0       0.0     Shingala        Kavin Hiren  ... 2021-04-07
# 85       0.0      46.0    Hanumaiah          Adi Srini  ... 2021-04-05
# 102      0.0       7.0     Banerjee             Meghna  ... 2021-04-06
# 117      0.0      29.0       Cusano  Rowan Christopher  ... 2021-04-08
# 143      0.0       0.0       Kumari             Simran  ... 2021-04-04
# 169      0.0       0.0  Stonebraker     Jonathan David  ... 2021-04-05
# 299      0.0       7.0        Patel        Mihir Rajen  ... 2021-04-01
# 309      0.0      12.0        Malik           Hurayrah  ... 2021-03-31
# 331      0.0      24.0         Moon         Kyoung Nam  ... 2021-04-05
# 360      0.0      19.0       Taylor                Van  ... 2021-04-02
# 376      0.0       7.0      Sanford  Caitlyn Elizabeth  ... 2021-03-31
# 383      0.0       0.0        Yerra    Sai Venkatasiva  ... 2021-03-29
# 411      0.0       0.0     Adhikari      Aniket Sachin  ... 2021-04-03
# 427      0.0       4.0     Peterson       Kyle Patrick  ... 2021-03-31
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade          TG  \
# 81                         0.238543          -25.0  63.853261   88.853261
# 83                         0.000000          -20.0  64.239130   84.239130
# 85                         0.000000          -35.0  65.000000  100.000000
# 102                        0.000000          -30.0  68.260870   98.260870
# 117                        0.000000          -30.0  70.000000  100.000000
# 143                        0.000000          -15.0  73.847692   88.847692
# 169                        0.000000          -15.0  76.686606   91.686606
# 299                        0.000000            0.0  90.664282   90.664282
# 309                        0.000000            0.0  91.778897   91.778897
# 331                        0.000000            0.0  93.478261   93.478261
# 360                        0.000000           -5.0  95.000000  100.000000
# 376                        0.000000            0.0  96.478261   96.478261
# 383                        0.000000            0.0  97.000000   97.000000
# 411                        0.000000            0.0  98.342818   98.342818
# 427                        0.000000            0.0  99.239130   99.239130
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 81           0.0           6.0  1.620000e+12                        0.0
# 83           4.0           6.0  1.620000e+12                        0.0
# 85           0.0           7.0  1.620000e+12                        0.0
# 102          0.0           7.0  1.620000e+12                        0.0
# 117          0.0           7.0  1.620000e+12                        0.0
# 143          7.0           7.0  1.620000e+12                        0.0
# 169          0.0           8.0  1.620000e+12                        0.0
# 299          0.0           9.0  1.620000e+12                        0.0
# 309         15.0           9.0  1.620000e+12                        0.0
# 331          0.0           9.0  1.620000e+12                        0.0
# 360          0.0          10.0  1.620000e+12                        0.0
# 376          0.0          10.0  1.620000e+12                        0.0
# 383          0.0          10.0  1.620000e+12                        0.0
# 411          0.0          10.0  1.620000e+12                        0.0
# 427          0.0          10.0  1.620000e+12                        0.0
#
#      Correctness/Testing %
# 81                     0.0
# 83                     0.0
# 85                     0.0
# 102                    0.0
# 117                    0.0
# 143                    0.0
# 169                    0.0
# 299                    0.0
# 309                    0.0
# 331                    0.0
# 360                    0.0
# 376                    0.0
# 383                    0.0
# 411                    0.0
# 427                    0.0
#
# [15 rows x 23 columns]

# %%
filtered3 = pd.concat([filterAbove85_3, filterLess85_3, filterNonVisit3])

# %%
# spearman correlation
coef,p = spearmanr(filtered3.posts,filtered3.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.487

# %%
# spearman correlation
coef,p = spearmanr(origin.posts,origin.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.152

# %%
# spearman correlation
coef,p = spearmanr(origin.NumVisit,origin.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.079

# %%
# spearman correlation
coef,p = spearmanr(filtered2.NumVisit,filtered2.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.507

# %%
ox = filtered2.NumVisit
oy = filtered2.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of visits to Office hours")
plt.ylabel("Final Grade of Project 4")
# Out:
# Text(0, 0.5, 'Final Grade of Project 4')

# %%
#struggle
filteredAbove85_Numvisit_4 = above_85_2[(above_85_2['NumVisit'] == 0) & (above_85_2['online'] == 0)]

filterAbove85_4 = above_85_2[(above_85_2['NumVisit'] > 0)& (above_85_2['online'] > 0) & (above_85_2["Max Sub"] > 9) & (above_85_2["Correctness by thirdsubmission"] <= 0.5)]
filterLess85_4 = less_85_2
filterNonVisit4 = filteredAbove85_Numvisit_4[(filteredAbove85_Numvisit_4["Max Sub"] > 9) & (filteredAbove85_Numvisit_4["Correctness by thirdsubmission"] <= 0.5) & (filteredAbove85_Numvisit_4["NumberOfDays"] > 3)]
filtered4 = pd.concat([filterAbove85_4, filterLess85_4, filterNonVisit4])

#non struggle
nonfilterAbove85_4 =  above_85_2[(above_85_2['NumVisit'] > 0)& (above_85_2['online'] > 0) & (above_85_2["Max Sub"] <= 9) & (above_85_2["Correctness by thirdsubmission"] > 0.5)]
nonfilterNonVisit4 = filteredAbove85_Numvisit_4[(filteredAbove85_Numvisit_4["Max Sub"] <= 9) & (filteredAbove85_Numvisit_4["Correctness by thirdsubmission"] > 0.5) & (filteredAbove85_Numvisit_4["NumberOfDays"] <= 3)]
nonfiltered4 = pd.concat([nonfilterAbove85_4, nonfilterNonVisit4])

#struggle temp
filterAbove85_t = above_85_2[(above_85_2["Max Sub"] > 10) & (above_85_2["Correctness by thirdsubmission"] <= 0.5)]
filterLess85_t = less_85_2
filtered5 = pd.concat([filterAbove85_t, filterLess85_t])

# %%
filtered5.count
# Out:
# <bound method DataFrame.count of       Course        User              Email  view  online  posts  answers  \
# 46   CS 2114       ramya       ramya@vt.edu   3.0    50.0    0.0      0.0
# 62   CS 2114       shans       shans@vt.edu  18.0    23.0    0.0      0.0
# 66   CS 2114   zharmeyer   zharmeyer@vt.edu  20.0    35.0    7.0      1.0
# 81   CS 2114      yunqin      yunqin@vt.edu   0.0    90.0    0.0      0.0
# 83   CS 2114   kshingala   kshingala@vt.edu  23.0    54.0    0.0      0.0
# ..       ...         ...                ...   ...     ...    ...      ...
# 196  CS 2114   lilykhoch   lilykhoch@vt.edu  37.0    64.0    0.0      0.0
# 197  CS 2114   adjeirenn   adjeirenn@vt.edu  42.0   117.0    0.0      0.0
# 198  CS 2114  chagerup24  chagerup24@vt.edu  18.0    40.0    0.0      0.0
# 199  CS 2114     jay1890     jay1890@vt.edu   0.0     0.0    0.0      0.0
# 201  CS 2114    atfuerst    atfuerst@vt.edu   0.0     8.0    0.0      0.0
#
#      NumVisit   Last Name           First Name  ...       Time  \
# 46        9.0       Aluri                Ramya  ... 2021-04-14
# 62        0.0  Somashekar                 Shan  ... 2021-04-10
# 66        8.0    Harmeyer          Zac Randall  ... 2021-04-08
# 81       82.0        Yang              Yun Qin  ... 2021-04-08
# 83        0.0    Shingala          Kavin Hiren  ... 2021-04-07
# ..        ...         ...                  ...  ...        ...
# 196       0.0  Khochareun            Lily Ling  ... 2021-04-08
# 197       0.0       Adjei  Renny Afriyie-Antwi  ... 2021-04-08
# 198       0.0     Hagerup         Colin Edward  ... 2021-04-07
# 199       0.0      Kapoor            Jay Ashok  ... 2021-04-08
# 201       0.0      Fuerst        Andrew Thomas  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade         TG  \
# 46                         0.151580          -35.0  52.518857  87.518857
# 62                         0.248883          -35.0  57.994071  92.994071
# 66                         0.000000          -30.0  58.718560  88.718560
# 81                         0.238543          -25.0  63.853261  88.853261
# 83                         0.000000          -20.0  64.239130  84.239130
# ..                              ...            ...        ...        ...
# 196                        0.722408            0.0  79.616643  79.616643
# 197                        0.503902            0.0  79.618841  79.618841
# 198                        0.000000            0.0  79.653311  79.653311
# 199                        0.302160            0.0  79.944964  79.944964
# 201                        0.599212            0.0  79.972425  79.972425
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 46      0.000000           5.0  1.620000e+12                   0.000000
# 62      0.000000           6.0  1.620000e+12                   0.000000
# 66      0.000000           6.0  1.620000e+12                   0.000000
# 81      0.000000           6.0  1.620000e+12                   0.000000
# 83      4.000000           6.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 196    25.284281           8.0  1.620000e+12                  25.284281
# 197    17.549407           8.0  1.620000e+12                  17.549407
# 198     0.000000           8.0  1.620000e+12                   0.000000
# 199     0.000000           8.0  1.620000e+12                   0.000000
# 201    20.321768           8.0  1.620000e+12                  20.321768
#
#      Correctness/Testing %
# 46                0.000000
# 62                0.000000
# 66                0.000000
# 81                0.000000
# 83                0.000000
# ..                     ...
# 196               0.722408
# 197               0.501412
# 198               0.000000
# 199               0.000000
# 201               0.580622
#
# [213 rows x 23 columns]>

# %%
# spearman correlation
coef,p = spearmanr(filtered5.view,filtered5.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
linregress(filtered5.view, filtered5.TG)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.412
# LinregressResult(slope=0.21934367901892604, intercept=73.94645623695382, rvalue=0.35800252996126647, pvalue=7.73143232007777e-08, stderr=0.03938353979477774)

# %%
# spearman correlation
coef,p = spearmanr(filterLess85_4.view,filterLess85_4.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.145

# %%
linregress(filterLess85_4.view, filterLess85_4.TG)
# Out:
# LinregressResult(slope=0.04152640717868057, intercept=66.19053314467745, rvalue=0.061635176978811775, pvalue=0.4964815491520048, stderr=0.06088205525263493)

# %%
# spearman correlation
coef,p = spearmanr(filterLess85_4.NumVisit,filterLess85_4.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: -0.005

# %%
linregress(filterLess85_4.NumVisit, filterLess85_4.TG)
# Out:
# LinregressResult(slope=0.42383606539400503, intercept=65.9069024507907, rvalue=0.13456677986190244, pvalue=0.1362025843257549, stderr=0.28256082275498196)

# %%
# spearman correlation
coef,p = spearmanr(filtered4.view,filtered4.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.388
# 6.992090233635509e-08

# %%
from scipy.stats import linregress
linregress(filtered4_remove.view, filtered4_remove.TG)
# Out:
# LinregressResult(slope=0.22947035811354208, intercept=71.37821001510336, rvalue=0.3604900772268647, pvalue=6.662531770409965e-07, stderr=0.04450354536788881)

# %%
# spearman correlation
coef,p = spearmanr(origin.view,origin.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.285
# 1.4503247445084095e-10

# %%
linregress(origin.view, origin.TG)
# Out:
# LinregressResult(slope=0.12221575284095498, intercept=84.80505637468426, rvalue=0.21717685155232952, pvalue=1.245868635884644e-06, stderr=0.024891888434532626)

# %%
# spearman correlation
coef,p = spearmanr(filtered4_remove.NumVisit,filtered4_remove.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.539
# 5.789283621384471e-15

# %%
linregress(filtered4_remove.NumVisit, filtered4_remove.TG)
# Out:
# LinregressResult(slope=0.8663015037367479, intercept=71.43490687851678, rvalue=0.4302922343570444, pvalue=1.652569146535916e-09, stderr=0.13621784922535463)

# %%
# spearman correlation
coef,p = spearmanr(origin.NumVisit,origin.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.079
# 0.08108967563452127

# %%
linregress(origin.NumVisit,origin.TG)
# Out:
# LinregressResult(slope=0.22490906949856634, intercept=86.41006014567915, rvalue=0.11666986052989671, pvalue=0.009817786087657938, stderr=0.08675764029142165)

# %%
ox = filtered4.view
oy = filtered4.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of viewing Project 4 related questions on Piazza")
plt.ylabel("Final Grade of Project 4")
rsquare = r2_score(oy,ox)
rsquare
# Out:
# -13.89557026156583

# %%
filtered4_remove = filtered4[(filtered4["NumVisit"] < 55) ]
filtered4_remove
# Out:
#       Course          User                Email  view  online  posts  answers  \
# 46   CS 2114         ramya         ramya@vt.edu   3.0    50.0    0.0      0.0
# 66   CS 2114     zharmeyer     zharmeyer@vt.edu  20.0    35.0    7.0      1.0
# 84   CS 2114  jakebarder29  jakebarder29@vt.edu   0.0    13.0    0.0      0.0
# 85   CS 2114      ahanumai      ahanumai@vt.edu  16.0    71.0    0.0      0.0
# 92   CS 2114      amounika      amounika@vt.edu   1.0    85.0    0.0      0.0
# ..       ...           ...                  ...   ...     ...    ...      ...
# 196  CS 2114     lilykhoch     lilykhoch@vt.edu  37.0    64.0    0.0      0.0
# 197  CS 2114     adjeirenn     adjeirenn@vt.edu  42.0   117.0    0.0      0.0
# 198  CS 2114    chagerup24    chagerup24@vt.edu  18.0    40.0    0.0      0.0
# 199  CS 2114       jay1890       jay1890@vt.edu   0.0     0.0    0.0      0.0
# 201  CS 2114      atfuerst      atfuerst@vt.edu   0.0     8.0    0.0      0.0
#
#      NumVisit   Last Name           First Name  ...       Time  \
# 46        9.0       Aluri                Ramya  ... 2021-04-14
# 66        8.0    Harmeyer          Zac Randall  ... 2021-04-08
# 84       24.0      Barder        Jake R Barder  ... 2021-04-10
# 85       46.0   Hanumaiah            Adi Srini  ... 2021-04-05
# 92       31.0    Abbineni              Mounika  ... 2021-04-11
# ..        ...         ...                  ...  ...        ...
# 196       0.0  Khochareun            Lily Ling  ... 2021-04-08
# 197       0.0       Adjei  Renny Afriyie-Antwi  ... 2021-04-08
# 198       0.0     Hagerup         Colin Edward  ... 2021-04-07
# 199       0.0      Kapoor            Jay Ashok  ... 2021-04-08
# 201       0.0      Fuerst        Andrew Thomas  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade          TG  \
# 46                         0.151580          -35.0  52.518857   87.518857
# 66                         0.000000          -30.0  58.718560   88.718560
# 84                         0.390635          -20.0  64.559813   84.559813
# 85                         0.000000          -35.0  65.000000  100.000000
# 92                         0.300505          -30.0  66.006329   96.006329
# ..                              ...            ...        ...         ...
# 196                        0.722408            0.0  79.616643   79.616643
# 197                        0.503902            0.0  79.618841   79.618841
# 198                        0.000000            0.0  79.653311   79.653311
# 199                        0.302160            0.0  79.944964   79.944964
# 201                        0.599212            0.0  79.972425   79.972425
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 46      0.000000           5.0  1.620000e+12                   0.000000
# 66      0.000000           6.0  1.620000e+12                   0.000000
# 84      0.000000           6.0  1.620000e+12                   0.000000
# 85      0.000000           7.0  1.620000e+12                   0.000000
# 92      0.000000           7.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 196    25.284281           8.0  1.620000e+12                  25.284281
# 197    17.549407           8.0  1.620000e+12                  17.549407
# 198     0.000000           8.0  1.620000e+12                   0.000000
# 199     0.000000           8.0  1.620000e+12                   0.000000
# 201    20.321768           8.0  1.620000e+12                  20.321768
#
#      Correctness/Testing %
# 46                0.000000
# 66                0.000000
# 84                0.000000
# 85                0.000000
# 92                0.000000
# ..                     ...
# 196               0.722408
# 197               0.501412
# 198               0.000000
# 199               0.000000
# 201               0.580622
#
# [180 rows x 23 columns]

# %%
ox = filtered4_remove.NumVisit
oy = filtered4_remove.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of visits to Office hours")
plt.ylabel("Final Grade of Project 4")
rsquare = r2_score(ox,oy)

# %%
ox = origin.view
oy = origin.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of viewing Project 4 related questions on Piazza")
plt.ylabel("Final Grade of Project 4")
rsquare = r2_score(ox,oy)
rsquare
# Out:
# -7.43148213189712

# %%
ox = origin.NumVisit
oy = origin.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of visits to Office hours")
plt.ylabel("Final Grade of Project 4")
rsquare = r2_score(ox,oy)
rsquare
# Out:
# -133.67355566347038

# %%
filtered4.count
# Out:
# <bound method DataFrame.count of       Course          User                Email  view  online  posts  answers  \
# 46   CS 2114         ramya         ramya@vt.edu   3.0    50.0    0.0      0.0
# 66   CS 2114     zharmeyer     zharmeyer@vt.edu  20.0    35.0    7.0      1.0
# 81   CS 2114        yunqin        yunqin@vt.edu   0.0    90.0    0.0      0.0
# 84   CS 2114  jakebarder29  jakebarder29@vt.edu   0.0    13.0    0.0      0.0
# 85   CS 2114      ahanumai      ahanumai@vt.edu  16.0    71.0    0.0      0.0
# ..       ...           ...                  ...   ...     ...    ...      ...
# 196  CS 2114     lilykhoch     lilykhoch@vt.edu  37.0    64.0    0.0      0.0
# 197  CS 2114     adjeirenn     adjeirenn@vt.edu  42.0   117.0    0.0      0.0
# 198  CS 2114    chagerup24    chagerup24@vt.edu  18.0    40.0    0.0      0.0
# 199  CS 2114       jay1890       jay1890@vt.edu   0.0     0.0    0.0      0.0
# 201  CS 2114      atfuerst      atfuerst@vt.edu   0.0     8.0    0.0      0.0
#
#      NumVisit   Last Name           First Name  ...       Time  \
# 46        9.0       Aluri                Ramya  ... 2021-04-14
# 66        8.0    Harmeyer          Zac Randall  ... 2021-04-08
# 81       82.0        Yang              Yun Qin  ... 2021-04-08
# 84       24.0      Barder        Jake R Barder  ... 2021-04-10
# 85       46.0   Hanumaiah            Adi Srini  ... 2021-04-05
# ..        ...         ...                  ...  ...        ...
# 196       0.0  Khochareun            Lily Ling  ... 2021-04-08
# 197       0.0       Adjei  Renny Afriyie-Antwi  ... 2021-04-08
# 198       0.0     Hagerup         Colin Edward  ... 2021-04-07
# 199       0.0      Kapoor            Jay Ashok  ... 2021-04-08
# 201       0.0      Fuerst        Andrew Thomas  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade          TG  \
# 46                         0.151580          -35.0  52.518857   87.518857
# 66                         0.000000          -30.0  58.718560   88.718560
# 81                         0.238543          -25.0  63.853261   88.853261
# 84                         0.390635          -20.0  64.559813   84.559813
# 85                         0.000000          -35.0  65.000000  100.000000
# ..                              ...            ...        ...         ...
# 196                        0.722408            0.0  79.616643   79.616643
# 197                        0.503902            0.0  79.618841   79.618841
# 198                        0.000000            0.0  79.653311   79.653311
# 199                        0.302160            0.0  79.944964   79.944964
# 201                        0.599212            0.0  79.972425   79.972425
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 46      0.000000           5.0  1.620000e+12                   0.000000
# 66      0.000000           6.0  1.620000e+12                   0.000000
# 81      0.000000           6.0  1.620000e+12                   0.000000
# 84      0.000000           6.0  1.620000e+12                   0.000000
# 85      0.000000           7.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 196    25.284281           8.0  1.620000e+12                  25.284281
# 197    17.549407           8.0  1.620000e+12                  17.549407
# 198     0.000000           8.0  1.620000e+12                   0.000000
# 199     0.000000           8.0  1.620000e+12                   0.000000
# 201    20.321768           8.0  1.620000e+12                  20.321768
#
#      Correctness/Testing %
# 46                0.000000
# 66                0.000000
# 81                0.000000
# 84                0.000000
# 85                0.000000
# ..                     ...
# 196               0.722408
# 197               0.501412
# 198               0.000000
# 199               0.000000
# 201               0.580622
#
# [181 rows x 23 columns]>

# %%
nonfiltered4.count
# Out:
# <bound method DataFrame.count of       Course             User                   Email   view  online  posts  \
# 61   CS 2114    gabriellan101    gabriellan101@vt.edu   29.0    91.0    8.0
# 86   CS 2114         zgates23         zgates23@vt.edu    1.0    64.0    0.0
# 97   CS 2114  nicholasdinonno  nicholasdinonno@vt.edu    0.0    23.0    0.0
# 148  CS 2114        amandar20        amandar20@vt.edu   12.0    86.0    0.0
# 181  CS 2114         choics20         choics20@vt.edu    0.0    11.0    0.0
# 185  CS 2114          lingyuz          lingyuz@vt.edu    3.0     6.0    0.0
# 188  CS 2114      kavyapolina      kavyapolina@vt.edu   11.0    28.0    0.0
# 194  CS 2114        marikoh20        marikoh20@vt.edu   11.0    38.0    0.0
# 208  CS 2114       humanerr0r       humanerr0r@vt.edu   21.0    40.0    0.0
# 216  CS 2114          habashi          habashi@vt.edu    0.0     7.0    0.0
# 219  CS 2114          mpadath          mpadath@vt.edu    0.0    32.0    0.0
# 229  CS 2114           cmkoe1           cmkoe1@vt.edu   16.0    49.0    0.0
# 230  CS 2114              ria              ria@vt.edu  115.0   306.0    0.0
# 233  CS 2114      mimcmahon20      mimcmahon20@vt.edu    1.0    19.0    0.0
# 238  CS 2114          alexn02          alexn02@vt.edu   25.0   132.0    0.0
# 243  CS 2114      seanmabella      seanmabella@vt.edu    0.0    18.0    0.0
# 249  CS 2114        ishasingh        ishasingh@vt.edu    1.0    39.0    0.0
# 266  CS 2114       nirajank20       nirajank20@vt.edu    0.0     8.0    0.0
# 282  CS 2114       antonioa19       antonioa19@vt.edu    0.0   123.0    0.0
# 284  CS 2114      janmichalak      janmichalak@vt.edu    4.0    34.0    0.0
# 301  CS 2114         jaredo19         jaredo19@vt.edu    8.0    73.0    1.0
# 305  CS 2114        cajeffery        cajeffery@vt.edu    3.0    31.0    0.0
# 323  CS 2114         simonwan         simonwan@vt.edu   15.0    42.0    0.0
# 343  CS 2114         gavinb01         gavinb01@vt.edu   20.0    29.0    0.0
# 354  CS 2114          homannm          homannm@vt.edu    0.0    12.0    0.0
# 369  CS 2114      stephanie20      stephanie20@vt.edu   14.0    16.0    0.0
# 378  CS 2114       nicholasam       nicholasam@vt.edu    0.0    15.0    0.0
# 382  CS 2114     andrewistfan     andrewistfan@vt.edu   18.0    75.0    0.0
# 398  CS 2114          jackf19          jackf19@vt.edu    7.0    56.0    0.0
# 432  CS 2114          techzjc          techzjc@vt.edu    6.0    52.0    0.0
# 434  CS 2114           willpb           willpb@vt.edu   14.0    38.0    0.0
# 458  CS 2114           gmjake           gmjake@vt.edu   14.0    44.0    3.0
# 468  CS 2114         lyizhe18         lyizhe18@vt.edu    7.0    94.0    0.0
# 480  CS 2114          nimesh9          nimesh9@vt.edu   38.0    77.0    0.0
# 167  CS 2114          ishitas          ishitas@vt.edu    0.0     0.0    0.0
# 306  CS 2114         matt0724         matt0724@vt.edu    0.0     0.0    0.0
# 339  CS 2114  caedenperickson  caedenperickson@vt.edu    0.0     0.0    0.0
# 479  CS 2114          nickg13          nickg13@vt.edu   20.0     0.0    0.0
#
#      answers  NumVisit  Last Name             First Name  ...       Time  \
# 61       0.0      27.0      Noble        Gabriella Marie  ... 2021-04-14
# 86       0.0      18.0      Gates             Zane Aumon  ... 2021-04-12
# 97       0.0      32.0    DiNonno           Nick Anthony  ... 2021-04-14
# 148      0.0      14.0      Rogas         Amanda Nichole  ... 2021-04-10
# 181      0.0       1.0       Choi             Chase Sang  ... 2021-04-11
# 185      0.0       1.0       Zhou                 Lingyu  ... 2021-04-09
# 188      0.0      10.0     Polina                  Kavya  ... 2021-04-12
# 194      0.0       1.0       Hart      Mariko Lavirginia  ... 2021-04-10
# 208      0.0       3.0       Chao     Christina Jun-Xing  ... 2021-04-09
# 216      0.0       5.0    Habashi         Daniel Monis S  ... 2021-04-05
# 219      0.0       6.0     Padath          Mathew Rajeev  ... 2021-04-09
# 229      0.0       4.0    Koehler          Chris Michael  ... 2021-04-08
# 230      0.0       2.0  Vadhavkar                    Ria  ... 2021-04-10
# 233      0.0       1.0    McMahon           Maguire Ivan  ... 2021-04-08
# 238      0.0       3.0       Natt            Alex Moriah  ... 2021-04-11
# 243      0.0       1.0     Abella  Sean Michael Virtucio  ... 2021-04-08
# 249      0.0       3.0      Singh                   Isha  ... 2021-04-09
# 266      0.0       2.0   Kadariya                Nirajan  ... 2021-04-11
# 282      0.0       3.0     Alonso      Antonio Guillermo  ... 2021-04-08
# 284      0.0       2.0   Michalak              Jan Jakub  ... 2021-04-07
# 301      0.0      13.0  Orendorff          Jared Michael  ... 2021-04-10
# 305      0.0       2.0    Jeffery        Caillyn Annette  ... 2021-03-31
# 323      0.0       5.0      Naung                  Simon  ... 2021-04-08
# 343      0.0       1.0    Bassett            Gavin Keith  ... 2021-04-08
# 354      0.0       2.0     Homann           Markus Henry  ... 2021-04-09
# 369      0.0       3.0     Grover         Stephanie Noel  ... 2021-04-08
# 378      0.0      12.0      Myers       Nicholas Anthony  ... 2021-04-08
# 382      0.0       1.0     Istfan          Andrew Jordan  ... 2021-04-08
# 398      0.0       2.0        Fox           Jack Francis  ... 2021-04-02
# 432      0.0       4.0       Zhao                   John  ... 2021-04-08
# 434      0.0       3.0      Becht        William Patrick  ... 2021-04-08
# 458      0.0       2.0     Michna           Jake Gregory  ... 2021-04-05
# 468      0.0      32.0        Liu                  Yizhe  ... 2021-04-05
# 480      0.0      12.0   Shrestha        Nimesh Nicholas  ... 2021-04-08
# 167      0.0       0.0       Soni        Ishita Shilpesh  ... 2021-04-09
# 306      0.0       0.0     Wilson                   Matt  ... 2021-04-07
# 339      0.0       0.0   Erickson          Caeden Philip  ... 2021-04-08
# 479      0.0       0.0   Gazzillo          Nick Pasquale  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus       Grade          TG  \
# 61                         0.758602          -35.0   57.713790   92.713790
# 86                         0.849581          -30.0   65.134969   95.134969
# 97                         0.855346          -25.0   67.037736   92.037736
# 148                        0.638773          -10.0   74.357058   84.357058
# 181                        0.650679          -15.0   77.913044   92.913044
# 185                        0.675685           -5.0   78.244039   83.244039
# 188                        0.872876          -20.0   78.609272   98.609272
# 194                        0.938698          -15.0   79.559546   94.559546
# 208                        0.887150           -5.0   81.235178   86.235178
# 216                        0.684358           -5.0   82.197863   87.197863
# 219                        0.568201           -5.0   82.574079   87.574079
# 229                        0.805857            0.0   83.730571   83.730571
# 230                        0.607708          -10.0   83.956522   93.956522
# 233                        0.719115            0.0   84.495437   84.495437
# 238                        0.869565          -15.0   85.000000  100.000000
# 243                        0.764878            0.0   85.322800   85.322800
# 249                        0.592056            0.0   85.721958   85.721958
# 266                        0.945868          -10.0   88.105384   98.105384
# 282                        0.652721            0.0   89.072709   89.072709
# 284                        0.712992            0.0   89.317935   89.317935
# 301                        0.884405           -5.0   90.954179   95.954179
# 305                        0.590809            0.0   91.292673   91.292673
# 323                        0.637007            0.0   92.850354   92.850354
# 343                        0.837752            0.0   94.321315   94.321315
# 354                        0.693033           -5.0   95.000000  100.000000
# 369                        0.832318            0.0   95.717391   95.717391
# 378                        0.903278            0.0   96.614741   96.614741
# 382                        0.967568            0.0   96.864865   96.864865
# 398                        0.923313            0.0   98.000000   98.000000
# 432                        0.889964            0.0   99.239130   99.239130
# 434                        0.886460            0.0   99.631579   99.631579
# 458                        0.987500            0.0  100.000000  100.000000
# 468                        0.956522            0.0  100.000000  100.000000
# 480                        0.922875            0.0  100.000000  100.000000
# 167                        0.591533           -5.0   76.628453   81.628453
# 306                        0.762148            0.0   91.328164   91.328164
# 339                        0.815425            0.0   94.000000   94.000000
# 479                        0.934783            0.0  100.000000  100.000000
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 61      0.000000           6.0  1.620000e+12                   0.000000
# 86      7.707940           7.0  1.620000e+12                  27.707939
# 97      5.000000           7.0  1.620000e+12                  30.000000
# 148     0.170183           7.0  1.620000e+12                  10.170183
# 181     0.000000           8.0  1.620000e+12                   0.000000
# 185     5.177236           8.0  1.620000e+12                  10.177236
# 188     3.547494           8.0  1.620000e+12                  18.547494
# 194     0.000000           8.0  1.620000e+12                   0.000000
# 208     0.000000           8.0  1.620000e+12                   0.000000
# 216    12.950801           8.0  1.620000e+12                  12.950801
# 219    19.757905           8.0  1.620000e+12                  19.757905
# 229    27.480961           8.0  1.620000e+12                  27.480961
# 230     0.000000           8.0  1.620000e+12                   0.000000
# 233    15.194611           8.0  1.620000e+12                  15.194611
# 238    23.284585           9.0  1.620000e+12                  26.284585
# 243     0.000000           9.0  1.620000e+12                   0.000000
# 249     0.000000           9.0  1.620000e+12                   0.000000
# 266    23.105384           9.0  1.620000e+12                  33.105384
# 282    19.462243           9.0  1.620000e+12                  19.462243
# 284    11.055526           9.0  1.620000e+12                  11.055526
# 301    22.819578           9.0  1.620000e+12                  27.819578
# 305     0.000000           9.0  1.620000e+12                   0.000000
# 323    12.147216           9.0  1.620000e+12                  12.147216
# 343    25.424178           9.0  1.620000e+12                  25.424178
# 354     0.000000          10.0  1.620000e+12                   0.000000
# 369    28.921641          10.0  1.620000e+12                  28.921641
# 378    32.614741          10.0  1.620000e+12                  31.614741
# 382    29.575043          10.0  1.620000e+12                  29.575043
# 398     0.000000          10.0  1.620000e+12                   0.000000
# 432     7.000000          10.0  1.620000e+12                   0.000000
# 434    28.422705          10.0  1.620000e+12                  28.422705
# 458    31.552009          10.0  1.620000e+12                  31.552009
# 468    32.503890          10.0  1.620000e+12                  32.503890
# 480     0.000000          10.0  1.620000e+12                   0.000000
# 167    13.470765           8.0  1.620000e+12                  18.470765
# 306     0.000000           9.0  1.620000e+12                   0.000000
# 339     0.000000           9.0  1.620000e+12                   0.000000
# 479     0.000000          10.0  1.620000e+12                   0.000000
#
#      Correctness/Testing %
# 61                0.000000
# 86                0.791655
# 97                0.857143
# 148               0.290577
# 181               0.000000
# 185               0.290778
# 188               0.529928
# 194               0.000000
# 208               0.000000
# 216               0.370023
# 219               0.564512
# 229               0.785170
# 230               0.000000
# 233               0.434132
# 238               0.750988
# 243               0.000000
# 249               0.000000
# 266               0.945868
# 282               0.556064
# 284               0.315872
# 301               0.794845
# 305               0.000000
# 323               0.347063
# 343               0.726405
# 354               0.000000
# 369               0.826333
# 378               0.903278
# 382               0.845001
# 398               0.000000
# 432               0.000000
# 434               0.812077
# 458               0.901486
# 468               0.928683
# 480               0.000000
# 167               0.527736
# 306               0.000000
# 339               0.000000
# 479               0.000000
#
# [38 rows x 23 columns]>

# %%
def GetDifferences(df1, df2):
  df = pd.concat([df1, df2]).reset_index(drop=True)
  idx = [diff[0] for diff in df.groupby(list(df.columns)).groups.values() if len(diff) == 1]
  return df.reindex(idx)

# %%
Maybe = GetDifferences(origin, filtered4)
filtered4
# Out:
#       Course          User                Email  view  online  posts  answers  \
# 46   CS 2114         ramya         ramya@vt.edu   3.0    50.0    0.0      0.0
# 66   CS 2114     zharmeyer     zharmeyer@vt.edu  20.0    35.0    7.0      1.0
# 81   CS 2114        yunqin        yunqin@vt.edu   0.0    90.0    0.0      0.0
# 84   CS 2114  jakebarder29  jakebarder29@vt.edu   0.0    13.0    0.0      0.0
# 85   CS 2114      ahanumai      ahanumai@vt.edu  16.0    71.0    0.0      0.0
# ..       ...           ...                  ...   ...     ...    ...      ...
# 196  CS 2114     lilykhoch     lilykhoch@vt.edu  37.0    64.0    0.0      0.0
# 197  CS 2114     adjeirenn     adjeirenn@vt.edu  42.0   117.0    0.0      0.0
# 198  CS 2114    chagerup24    chagerup24@vt.edu  18.0    40.0    0.0      0.0
# 199  CS 2114       jay1890       jay1890@vt.edu   0.0     0.0    0.0      0.0
# 201  CS 2114      atfuerst      atfuerst@vt.edu   0.0     8.0    0.0      0.0
#
#      NumVisit   Last Name           First Name  ...       Time  \
# 46        9.0       Aluri                Ramya  ... 2021-04-14
# 66        8.0    Harmeyer          Zac Randall  ... 2021-04-08
# 81       82.0        Yang              Yun Qin  ... 2021-04-08
# 84       24.0      Barder        Jake R Barder  ... 2021-04-10
# 85       46.0   Hanumaiah            Adi Srini  ... 2021-04-05
# ..        ...         ...                  ...  ...        ...
# 196       0.0  Khochareun            Lily Ling  ... 2021-04-08
# 197       0.0       Adjei  Renny Afriyie-Antwi  ... 2021-04-08
# 198       0.0     Hagerup         Colin Edward  ... 2021-04-07
# 199       0.0      Kapoor            Jay Ashok  ... 2021-04-08
# 201       0.0      Fuerst        Andrew Thomas  ... 2021-04-08
#
#      Correctness by thirdsubmission  Penalty/Bonus      Grade          TG  \
# 46                         0.151580          -35.0  52.518857   87.518857
# 66                         0.000000          -30.0  58.718560   88.718560
# 81                         0.238543          -25.0  63.853261   88.853261
# 84                         0.390635          -20.0  64.559813   84.559813
# 85                         0.000000          -35.0  65.000000  100.000000
# ..                              ...            ...        ...         ...
# 196                        0.722408            0.0  79.616643   79.616643
# 197                        0.503902            0.0  79.618841   79.618841
# 198                        0.000000            0.0  79.653311   79.653311
# 199                        0.302160            0.0  79.944964   79.944964
# 201                        0.599212            0.0  79.972425   79.972425
#
#      Total Score  distribution     Timestamp  Correctness/Testing Score  \
# 46      0.000000           5.0  1.620000e+12                   0.000000
# 66      0.000000           6.0  1.620000e+12                   0.000000
# 81      0.000000           6.0  1.620000e+12                   0.000000
# 84      0.000000           6.0  1.620000e+12                   0.000000
# 85      0.000000           7.0  1.620000e+12                   0.000000
# ..           ...           ...           ...                        ...
# 196    25.284281           8.0  1.620000e+12                  25.284281
# 197    17.549407           8.0  1.620000e+12                  17.549407
# 198     0.000000           8.0  1.620000e+12                   0.000000
# 199     0.000000           8.0  1.620000e+12                   0.000000
# 201    20.321768           8.0  1.620000e+12                  20.321768
#
#      Correctness/Testing %
# 46                0.000000
# 66                0.000000
# 81                0.000000
# 84                0.000000
# 85                0.000000
# ..                     ...
# 196               0.722408
# 197               0.501412
# 198               0.000000
# 199               0.000000
# 201               0.580622
#
# [181 rows x 23 columns]

# %%
# spearman correlation
coef,p = spearmanr(Maybe.NumVisit,Maybe.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.007
# 0.9018804690576183

# %%
# spearman correlation
coef,p = spearmanr(Maybe.view,Maybe.TG)
print('Spearmans correlation coefficient overall help-seeking activity vs grade: %.3f' % coef)
print(p)
# Out:
# Spearmans correlation coefficient overall help-seeking activity vs grade: 0.142
# 0.012688706129239986

# %%
filtered4['view'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 46      3.0
# 66     20.0
# 81      0.0
# 84      0.0
# 85     16.0
#        ...
# 196    37.0
# 197    42.0
# 198    18.0
# 199     0.0
# 201     0.0
# Name: view, Length: 181, dtype: float64>

# %%
Maybe['view'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 441    17.0
# 375    32.0
# 210     5.0
# 88      1.0
# 223     8.0
#        ...
# 351    10.0
# 86      1.0
# 332    33.0
# 420    15.0
# 236    10.0
# Name: view, Length: 308, dtype: float64>

# %%
filtered4['online'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 46      50.0
# 66      35.0
# 81      90.0
# 84      13.0
# 85      71.0
#        ...
# 196     64.0
# 197    117.0
# 198     40.0
# 199      0.0
# 201      8.0
# Name: online, Length: 181, dtype: float64>

# %%
filtered4['posts'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 46     0.0
# 66     7.0
# 81     0.0
# 84     0.0
# 85     0.0
#       ...
# 196    0.0
# 197    0.0
# 198    0.0
# 199    0.0
# 201    0.0
# Name: posts, Length: 181, dtype: float64>

# %%
Maybe['online'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 441    25.0
# 375    90.0
# 210    21.0
# 88     12.0
# 223    39.0
#        ...
# 351     4.0
# 86     64.0
# 332    10.0
# 420    22.0
# 236     8.0
# Name: online, Length: 308, dtype: float64>

# %%
Maybe['posts'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 441    0.0
# 375    0.0
# 210    0.0
# 88     0.0
# 223    0.0
#       ...
# 351    0.0
# 86     0.0
# 332    0.0
# 420    0.0
# 236    0.0
# Name: posts, Length: 308, dtype: float64>

# %%
ox = Maybe.NumVisit
oy = Maybe.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of visits to Office hours")
plt.ylabel("Final Grade of Project 4")
b
# Out:
# 93.84090398922021

# %%
ox = Maybe.view
oy = Maybe.TG
plt.scatter(ox,oy,color='#003F72')
m, b = np.polyfit(ox, oy, 1)
plt.ylim(0,120)
plt.plot(ox, m*ox+b, color = 'red')
plt.xlabel("Number of viweing Project 4 related questions on Piazza")
plt.ylabel("Final Grade of Project 4")
b
# Out:
# 93.56395699851419

# %%
linregress(Maybe.NumVisit, Maybe.TG)
# Out:
# LinregressResult(slope=0.07938959885551328, intercept=93.84090398922021, rvalue=0.0704795097607139, pvalue=0.21742082487227019, stderr=0.06423307051935145)

# %%
linregress(Maybe.view, Maybe.TG)
# Out:
# LinregressResult(slope=0.021767805235437216, intercept=93.56395699851417, rvalue=0.09739736329678299, pvalue=0.08792881423852685, stderr=0.012715603724763673)
